# %%
import pandas as pd

# %%
housig_df=pd.read_csv(r'C:\Users\Bhaskar\Desktop\files\train.csv')

# %%
housig_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
housig_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housig_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
housig_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numeric_list=['int16','int32','int64','float16','float32','float64']
numberical_cols=list(housig_df.select_dtypes(include=numeric_list).columns)

# %%
numberical_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
housig_df=housig_df[numberical_cols]

# %%
housig_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
housig_df.drop(['Id'],axis=1)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
housig_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=housig_df.drop(['SalePrice'],axis=1)
y=housig_df.SalePrice

# %%
x_train,x_test,y_train,y_test=train_test_split(housig_df.drop(labels=['SalePrice'],axis=1),
                                                              housig_df['SalePrice'],
                                                              test_size=0.3,random_state=42)

# %%
x_train.head()
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 135    136          20         80.0    10400            7            6
# 1452  1453         180         35.0     3675            5            5
# 762    763          60         72.0     8640            7            5
# 932    933          20         84.0    11670            9            5
# 435    436          60         43.0    10667            7            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# 135        1970          1970       288.0           0  ...         530
# 1452       2005          2005        80.0         547  ...         525
# 762        2009          2009         0.0          24  ...         614
# 932        2006          2006       302.0           0  ...         788
# 435        1996          1996         0.0         385  ...         550
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# ...

# %%
x_train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      190
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         3
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
mutual=mutual_info_regression(x_train.fillna(0),y_train)

# %%
mutual
# Out:
# array([0.00490103, 0.28811872, 0.18911159, 0.15171299, 0.52523356,
#        0.10859306, 0.32210282, 0.24293263, 0.0721181 , 0.14303239,
#        0.00706442, 0.14658238, 0.31441855, 0.28387781, 0.21104608,
#        0.00375984, 0.44951916, 0.02174111, 0.00943009, 0.24122866,
#        0.06648801, 0.06593725, 0.0225363 , 0.16587812, 0.15287429,
#        0.25907767, 0.35745536, 0.344982  , 0.06596055, 0.14103552,
#        0.0317863 , 0.        , 0.03361939, 0.        , 0.        ,
#        0.00382679, 0.0097007 ])

# %%
mutual=pd.Series(mutual)
mutual.index=x_train.columns
mutual.sort_values(ascending=False)
# Out:
# OverallQual      0.525234
# GrLivArea        0.449519
# GarageCars       0.357455
# GarageArea       0.344982
# YearBuilt        0.322103
# TotalBsmtSF      0.314419
# MSSubClass       0.288119
# 1stFlrSF         0.283878
# GarageYrBlt      0.259078
# YearRemodAdd     0.242933
# FullBath         0.241229
# 2ndFlrSF         0.211046
# LotFrontage      0.189112
# TotRmsAbvGrd     0.165878
# Fireplaces       0.152874
# LotArea          0.151713
# BsmtUnfSF        0.146582
# BsmtFinSF1       0.143032
# OpenPorchSF      0.141036
# OverallCond      0.108593
# MasVnrArea       0.072118
# HalfBath         0.066488
# WoodDeckSF       0.065961
# BedroomAbvGr     0.065937
# ScreenPorch      0.033619
# EnclosedPorch    0.031786
# KitchenAbvGr     0.022536
# BsmtFullBath     0.021741
# YrSold           0.009701
# BsmtHalfBath     0.009430
# BsmtFinSF2       0.007064
# Id               0.004901
# MoSold           0.003827
# LowQualFinSF     0.003760
# 3SsnPorch        0.000000
# ...

# %%
mutual.sort_values(ascending=False).plot.bar(figsize=(15,7))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest

# %%
selc_five_col=SelectKBest(mutual,k=5)
selc_five_col.fit(x_train,y_train)
x_train.columns[selc_five_col.get_support()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-692a7f773e04> in <module>
#       1 selc_five_col=SelectKBest(mutual,k=5)
# ----> 2 selc_five_col.fit(x_train,y_train)
#       3 x_train.columns[selc_five_col.get_support()]
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     342         self : object
#     343         """
# --> 344         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
#     345                                    multi_output=True)
#     346
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
from sklearn.feature_selection import SelectPercentile

# %%
selc=SelectPercentile(mutual,percentile=20)
selc.fit(x_train.fillna(0),y_train)
x_train.columns[selc.ge]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-08546594f707> in <module>
#       1 selc=SelectPercentile(mutual,percentile=20)
# ----> 2 selc.fit(x_train.fillna(0),y_train)
#       3 x_train.columns[selc.ge]
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     346
#     347         if not callable(self.score_func):
# --> 348             raise TypeError("The score function should be a callable, %s (%s) "
#     349                             "was passed."
#     350                             % (self.score_func, type(self.score_func)))
#
# TypeError: The score function should be a callable, Id               0.004901
# MSSubClass       0.288119
# LotFrontage      0.189112
# LotArea          0.151713
# OverallQual      0.525234
# OverallCond      0.108593
# YearBuilt        0.322103
# ...
